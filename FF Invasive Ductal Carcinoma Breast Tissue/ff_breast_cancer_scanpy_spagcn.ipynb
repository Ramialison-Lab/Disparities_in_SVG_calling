# %% [markdown]
# ## Identify SVGs in FF Invasive Ductal Carcinoma Breast Tissue using SpaGCN

# %%
import os,csv,re
import pandas as pd
import numpy as np
import numba
import scanpy as sc
import math
import SpaGCN as spg
from scipy.sparse import issparse
import random, torch
import warnings
warnings.filterwarnings("ignore")
import matplotlib.colors as clr
import matplotlib.pyplot as plt
import SpaGCN as spg
import cv2

# %%
##Read in preprocessed adata
#Read in gene expression and spatial location
adata=sc.read("ff_breast_cancer.h5ad")

#read in spatial positions
spatial=pd.read_csv("V1_Breast_Cancer_Block_A_Section_1/spatial/tissue_positions_list.csv",sep=",",header=None,na_filter=False,index_col=0,names=["barcode", "in_tissue", "array_row", "array_col","pxl_row_in_fullres","pxl_col_in_fullres"]) 

#Read in hitology image
img=cv2.imread("V1_Breast_Cancer_Block_A_Section_1/spatial/tissue_hires_image.tiff")

# %%
##re index spatial table according to barcodes in adata
sorted_barcodes = list(adata.obs_names)

spatial = spatial.reindex(sorted_barcodes)

# %%
#Set coordinates
x_array=adata.obs["array_row"].tolist()
y_array=adata.obs["array_col"].tolist()
x_pixel=spatial["pxl_row_in_fullres"].tolist()
y_pixel=spatial["pxl_col_in_fullres"].tolist()

print(img)
#Test coordinates on the image
img_new=img.copy()
for i in range(len(x_pixel)):
    x=x_pixel[i]
    y=y_pixel[i]
    img[int(x-20):int(x+20), int(y-20):int(y+20),:]=0

cv2.imwrite('ff_human_breast_cancer_scanpy_processed_image_map.jpg', img_new)
# Out:
# [[[188 191 189]
#   [188 192 190]
#   [189 191 189]
#   ...
#   [188 192 191]
#   [186 191 189]
#   [189 193 190]]
#
#  [[188 191 190]
#   [188 192 189]
#   [188 192 190]
#   ...
#   [188 192 191]
#   [188 191 189]
#   [188 193 190]]
#
#  [[188 192 190]
#   [188 192 190]
#   [188 192 190]
#   ...
#   [188 192 191]
#   [188 192 191]
#   [189 192 190]]
#
#  ...
#
#  [[189 191 189]
#   [188 191 189]
#   [188 191 189]
#   ...
#   [187 190 187]
#   [186 189 187]
#   [186 189 187]]
#
#  [[188 191 188]
#   [188 190 189]
#   [188 191 189]
#   ...
#   [186 190 187]
#   [186 189 187]
#   [186 190 187]]
#
#  [[188 190 188]
#   [188 190 188]
#   [189 191 188]
#   ...
#   [186 190 188]
#   [186 190 187]
#   [186 189 187]]]
# True

# %%
#Calculate adjacent matrix
s=1
b=49
#print(img)
#adj=spg.calculate_adj_matrix(x=x_pixel,y=y_pixel, x_pixel=x_pixel, y_pixel=y_pixel, image=img, beta=b, alpha=s, histology=True)
#If histlogy image is not available, SpaGCN can calculate the adjacent matrix using the fnction below
adj=spg.calculate_adj_matrix(x=x_pixel,y=y_pixel, histology=False)
print(adj)
np.savetxt('ff_human_breast_cancer_adj.csv', adj, delimiter=',')
# Out:
# Calculateing adj matrix using xy only...
# [[    0.     11531.981  12172.211  ...  8408.998  10113.489  10308.903 ]
#  [11531.981      0.      2965.8894 ...  3149.5564  1520.0662  3500.6543]
#  [12172.211   2965.8894     0.     ...  4744.0938  3862.6013  1969.3978]
#  ...
#  [ 8408.998   3149.5564  4744.0938 ...     0.      1706.5708  3705.9834]
#  [10113.489   1520.0662  3862.6013 ...  1706.5708     0.      3586.7124]
#  [10308.903   3500.6543  1969.3978 ...  3705.9834  3586.7124     0.    ]]

# %%
#set hyper-parameters
p=0.5 
#Find the l value given p
l=spg.search_l(p, adj, start=0.01, end=1000, tol=0.01, max_run=100)
print(l)
# Out:
# Run 1: l [0.01, 1000], p [0.0, 74.49452308851099]
# Run 2: l [0.01, 500.005], p [0.0, 19.475013732910156]
# Run 3: l [0.01, 250.0075], p [0.0, 4.418020248413086]
# Run 4: l [125.00874999999999, 250.0075], p [0.4886806011199951, 4.418020248413086]
# Run 5: l [125.00874999999999, 187.508125], p [0.4886806011199951, 2.122544765472412]
# Run 6: l [125.00874999999999, 156.2584375], p [0.4886806011199951, 1.2107300758361816]
# Run 7: l [125.00874999999999, 140.63359375], p [0.4886806011199951, 0.8212234973907471]
# Run 8: l [125.00874999999999, 132.821171875], p [0.4886806011199951, 0.6467751264572144]
# Run 9: l [125.00874999999999, 128.91496093749998], p [0.4886806011199951, 0.5655173063278198]
# Run 10: l [125.00874999999999, 126.96185546874999], p [0.4886806011199951, 0.5265238285064697]
# recommended l =  125.98530273437498
# 125.98530273437498

# %%
#Going with 14 clusters as this is what I got from previous data - this has 0 index
n_clusters=14
#Set seed
r_seed=t_seed=n_seed=100
#Search for suitable resolution
res=spg.search_res(adata, adj, l, n_clusters, start=0.7, step=0.1, tol=5e-3, lr=0.05, max_epochs=20, r_seed=r_seed, t_seed=t_seed, n_seed=n_seed)
# Out:
# Start at res =  0.7 step =  0.1
# Initializing cluster centers with louvain, resolution =  0.7
# Epoch  0
# Epoch  10
# Res =  0.7 Num of clusters =  13
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Res =  0.7999999999999999 Num of clusters =  14
# recommended res =  0.7999999999999999

# %%
clf=spg.SpaGCN()
clf.set_l(l)
#Set seed
random.seed(r_seed)
torch.manual_seed(t_seed)
np.random.seed(n_seed)
#Run
clf.train(adata,adj,init_spa=True,init="louvain",res=res, tol=5e-3, lr=0.05, max_epochs=200)
y_pred, prob=clf.predict()
adata.obs["pred"]= y_pred
adata.obs["pred"]=adata.obs["pred"].astype('category')
#Do cluster refinement(optional)
#shape="hexagon" for Visium data, "square" for ST data.
adj_2d=spg.calculate_adj_matrix(x=x_array,y=y_array, histology=False)
refined_pred=spg.refine(sample_id=adata.obs.index.tolist(), pred=adata.obs["pred"].tolist(), dis=adj_2d, shape="hexagon")
adata.obs["refined_pred"]=refined_pred
adata.obs["refined_pred"]=adata.obs["refined_pred"].astype('category')
# Out:
# Initializing cluster centers with louvain, resolution =  0.7999999999999999
# Epoch  0
# Epoch  10
# Epoch  20
# Epoch  30
# delta_label  0.0046204620462046205 < tol  0.005
# Reach tolerance threshold. Stopping training.
# Total epoch: 34
# Calculateing adj matrix using xy only...

# %%
#Plot spatial domains
#Set colors used
plot_color=["#F56867","#FEB915","#C798EE","#59BE86","#7495D3","#D1D1D1","#6D1A9C","#15821E","#3A84E6","#997273","#787878","#DB4C6C","#9E7A7A","#554236","#AF5F3C","#93796C","#F9BD3F","#DAB370","#877F6C","#268785"]
#Plot spatial domains
domains="pred"
num_celltype=len(adata.obs[domains].unique())
adata.uns[domains+"_colors"]=list(plot_color[:num_celltype])
#ax=sc.pl.scatter(adata,alpha=1,x="y_pixel",y="x_pixel",color=domains,title=domains,color_map=plot_color,show=False,size=100000/adata.shape[0])
#change above line so it comes from adata input
ax=sc.pl.scatter(adata,alpha=1,x="array_row",y="array_col",color=domains,title=domains,color_map=plot_color,show=False,size=100000/adata.shape[0])
ax.set_aspect('equal', 'box')
ax.axes.invert_yaxis()
plt.savefig("ff_human_breast_cancer_spagcn_pred.png", dpi=600)
plt.close()

#Plot refined spatial domains
domains="refined_pred"
num_celltype=len(adata.obs[domains].unique())
adata.uns[domains+"_colors"]=list(plot_color[:num_celltype])
ax=sc.pl.scatter(adata,alpha=1,x="array_row",y="array_col",color=domains,title=domains,color_map=plot_color,show=False,size=100000/adata.shape[0])
ax.set_aspect('equal', 'box')
ax.axes.invert_yaxis()
plt.savefig("ff_human_breast_cancer_spagcn_refined_pred.png", dpi=600)
plt.close()

# %%
#Use domain 0 as an example
target=0
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 258.84939759036143]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 83.24096385542168]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 31.18975903614458]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [7.081325301204819, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [7.081325301204819, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 7: radius [3.063392600044608, 3.2989896088838577], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 8: radius [3.063392600044608, 3.181191104464233], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 9: radius [3.1222918522544205, 3.181191104464233], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 10: radius [3.1517414783593267, 3.181191104464233], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 11: radius [3.1517414783593267, 3.16646629141178], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 12: radius [3.1591038848855533, 3.16646629141178], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 13: radius [3.1591038848855533, 3.1627850881486665], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 14: radius [3.16094448651711, 3.1627850881486665], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 15: radius [3.1618647873328882, 3.1627850881486665], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 16: radius [3.1618647873328882, 3.1623249377407774], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 17: radius [3.162094862536833, 3.1623249377407774], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 18: radius [3.162209900138805, 3.1623249377407774], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 19: radius [3.1622674189397912, 3.1623249377407774], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 20: radius [3.1622674189397912, 3.1622961783402843], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 21: radius [3.1622674189397912, 3.1622817986400378], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 22: radius [3.1622746087899145, 3.1622817986400378], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 23: radius [3.1622746087899145, 3.162278203714976], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 24: radius [3.1622764062524453, 3.162278203714976], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 25: radius [3.1622773049837107, 3.162278203714976], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 26: radius [3.1622773049837107, 3.1622777543493434], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 27: radius [3.162277529666527, 3.1622777543493434], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 28: radius [3.1622776420079353, 3.1622777543493434], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 29: radius [3.1622776420079353, 3.1622776981786394], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 30: radius [3.1622776420079353, 3.162277670093287], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 31: radius [3.162277656050611, 3.162277670093287], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 32: radius [3.162277656050611, 3.162277663071949], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 33: radius [3.16227765956128, 3.162277663071949], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 34: radius [3.16227765956128, 3.1622776613166144], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 35: radius [3.16227765956128, 3.162277660438947], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 36: radius [3.1622776600001137, 3.162277660438947], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 37: radius [3.1622776600001137, 3.16227766021953], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 38: radius [3.162277660109822, 3.16227766021953], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 39: radius [3.1622776601646763, 3.16227766021953], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 40: radius [3.1622776601646763, 3.162277660192103], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 41: radius [3.1622776601646763, 3.1622776601783897], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 42: radius [3.1622776601646763, 3.162277660171533], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 43: radius [3.1622776601681046, 3.162277660171533], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 44: radius [3.1622776601681046, 3.162277660169819], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 45: radius [3.1622776601681046, 3.1622776601689617], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 46: radius [3.1622776601681046, 3.162277660168533], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 47: radius [3.1622776601683187, 3.162277660168533], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 48: radius [3.1622776601683187, 3.162277660168426], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 49: radius [3.1622776601683724, 3.162277660168426], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 50: radius [3.1622776601683724, 3.1622776601683995], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 51: radius [3.1622776601683724, 3.162277660168386], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 52: radius [3.162277660168379, 3.162277660168386], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 53: radius [3.162277660168379, 3.1622776601683826], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 54: radius [3.162277660168379, 3.162277660168381], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 55: radius [3.162277660168379, 3.16227766016838], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 56: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 57: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 58: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 59: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 60: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 61: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 62: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 63: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 64: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 65: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 66: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 67: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 68: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 69: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 70: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 71: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 72: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 73: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 74: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 75: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 76: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 77: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 78: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 79: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 80: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 81: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 82: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 83: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 84: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 85: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 86: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 87: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 88: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 89: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 90: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 91: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 92: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 93: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 94: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 95: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 96: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 97: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 98: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 99: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 100: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Calculateing adj matrix using xy only...
# Run 101: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.891566265060241, 15.487951807228916]
# Exact radius not found, closest values are:
# radius=3.162277660168379: num_nbr=9.891566265060241
# radius=3.1622776601683795: num_nbr=15.487951807228916
# 3.1622776601683795
# radius= 3.1622776601683795 average number of neighbors for each spot is 15.487951807228916
#  Cluster 0 has neighbors:
# Dmain  5 :  635
# Dmain  10 :  342
# Dmain  12 :  254
# Dmain  4 :  197
# Dmain  7 :  178
# [5, 10, 12, 4, 7]
# SVGs for domain  0 : ['IGHG1', 'TIMP1', 'C3', 'SFRP2', 'IGFBP7', 'IGHA1', 'LUM', 'DCN', 'TXNIP', 'IGLC1', 'IGHM', 'C1S', 'FBLN1', 'CCDC80', 'C1R', 'ZFP36L2', 'LRP1', 'IGLC3', 'EMILIN1', 'RARRES2', 'APOD', 'FOS', 'TRBC2', 'JCHAIN', 'CXCL12']

# %%
target=1
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 235.49279538904898]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 84.9135446685879]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 33.10374639769452]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 16.371757925072046]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [7.412103746397695, 16.371757925072046]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [7.412103746397695, 16.371757925072046]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=10.39193083573487
# radius= 3.1622776601683795 average number of neighbors for each spot is 16.371757925072046
#  Cluster 1 has neighbors:
# Dmain  12 :  176
# Dmain  14 :  129
# [12, 14]
# SVGs for domain  1 : ['GFRA1', 'MAGED2', 'SEC61G', 'LDLRAD4', 'TCEAL1', 'TSPAN13', 'DEGS1', 'BHLHE40', 'CACYBP', 'PRKACB', 'H2AFZ', 'NDUFC1', 'TCEAL3', 'HMGB2', 'STMN1', 'AGR3', 'HSPH1', 'TTLL12', 'TNRC18', 'SREBF1', 'CRAT', 'CKS2', 'MYC', 'TOP2A', 'ADIPOR2', 'SLC7A2', 'CISH', 'SLC4A8', 'IL20', 'SIRLNT', 'CNTD2', 'PTTG1', 'PTPN1', 'PHGR1', 'SLC25A4', 'AGL', 'VSTM2A', 'SPAG6', 'ARPP21', 'Z82214.2']

# %%
target=2
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 311.531914893617]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 105.12765957446808]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 38.54609929078014]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 18.46808510638298]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [8.131205673758865, 18.46808510638298]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [8.131205673758865, 18.46808510638298]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=11.581560283687944
# radius= 3.1622776601683795 average number of neighbors for each spot is 18.46808510638298
#  Cluster 2 has neighbors:
# Dmain  11 :  622
# Dmain  7 :  238
# Dmain  5 :  166
# Dmain  12 :  129
# [11, 7, 5, 12]
# SVGs for domain  2 : ['DEGS2', 'MGST3', 'CTTN', 'B4GALT1', 'MARCKSL1', 'CCT3', 'LAGE3', 'MT1E', 'CACYBP', 'TXN', 'HSPE1', 'DBI', 'ELF3', 'CTNNA1', 'SNRPE', 'AQP3', 'EFNA1', 'S100A13', 'CRISP3', 'CCND1', 'TNFSF10', 'AGR2', 'TSPAN13', 'PSMA6', 'S100A14', 'EFHD1', 'ERBB3', 'MUC5B', 'PLPP2', 'TACSTD2', 'SEC61G', 'EIF3H', 'NEDD4L', 'SERHL2', 'TMEM165', 'IFITM1', 'CPNE7', 'ANO1', 'SLC1A5', 'SLITRK6', 'TOMM5', 'AGR3', 'SRP72', 'ZNF217', 'TMEM106C', 'H2AFV', 'FADD', 'RAMP1', 'CKS1B', 'HMGB2', 'STMN1', 'ATP9A', 'SPTSSA', 'KCTD3', 'PDLIM1', 'PFDN2', 'SHISA2', 'OCLN', 'VTCN1', 'PAICS', 'NAIP', 'UBE2S', 'POLR2B', 'TMEM183A', 'AGPAT2', 'TGIF1', 'SNRPD1', 'NEBL', 'MYO6', 'GDF15', 'HMGB3', 'CEACAM6', 'C6orf141', 'TOP2A', 'SORD', 'DNAJC1', 'FGFR1', 'SPP1', 'UGDH', 'FAM177A1', 'ASCL2', 'UBE2C', 'CBWD5', 'MIDN', 'ADIPOR2', 'CYP4B1', 'SRD5A3', 'PTGES', 'IL20', 'NPNT', 'ITPRIPL2', 'MAB21L4', 'LTO1', 'SCUBE2', 'PLEKHS1', 'PDZK1IP1']

# %%
target=3
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 344.2432432432432]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 111.13243243243244]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 40.851351351351354]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 19.45945945945946]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [8.475675675675676, 19.45945945945946]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [8.475675675675676, 19.45945945945946]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=12.162162162162161
# radius= 3.1622776601683795 average number of neighbors for each spot is 19.45945945945946
#  Cluster 3 has neighbors:
# Dmain  5 :  681
# Dmain  9 :  329
# [5, 9]
# SVGs for domain  3 : ['SCD', 'TOB1', 'TNFSF10', 'RAB11FIP1', 'CFB', 'JUND', 'HIST1H2AC', 'PSMB8', 'YWHAE', 'BAMBI', 'NDUFB4', 'MAT2A', 'POLR2K', 'TFF1', 'CLDN7', 'SCGB1D2', 'RHOB', 'TBC1D9', 'IL6ST', 'CPB1', 'FAM234B', 'WWP1', 'NDUFB9', 'TAP1', 'PSME2', 'PDIA3', 'UQCRB', 'PLEKHF2', 'CSTA', 'TMEM256', 'ERLIN2', 'WASHC5', 'HEBP1', 'ENY2', 'HACD3', 'CREB3L4', 'UGCG', 'TPD52', 'RNF213', 'ACADSB', 'SPCS1', 'SEC61G', 'RABEP1', 'IFIT1', 'ABHD2', 'SCGB2A2', 'TP53INP1', 'IFITM1', 'CPNE3', 'ZNF706', 'PPT1', 'VIRMA', 'ACLY', 'COX17', 'PSMB9', 'FARP1', 'LYPLA1', 'MRPL13', 'BCL2', 'PLPBP', 'IRF9', 'GLUD1', 'HERPUD1', 'TXNDC17', 'SLC38A1', 'PRLR', 'SMS', 'HK2', 'PSMD11', 'C1QBP', 'HADHB', 'SMIM14', 'CGA', 'TCIM', 'KLHDC7B', 'SLC5A6', 'HIST2H2BE', 'SIX1', 'REPS2', 'ZNF552', 'CXCL9', 'LINC02224', 'SQLE', 'APOL2', 'BOLA3', 'ATP6V1H', 'SIAH2', 'DDIT3', 'SLC7A2', 'EMC6', 'HCP5', 'DYNC1LI1', 'FCGR3B', 'IFIT3', 'NDUFAF6', 'AC093001.1', 'MRPS28', 'SLC39A11', 'SCUBE3', 'LINC00578', 'NEU1', 'GBP4']

# %%
target=4
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 263.64312267657994]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 99.85130111524164]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 38.014869888475836]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 18.304832713754646]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [8.066914498141264, 18.304832713754646]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [8.066914498141264, 18.304832713754646]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=11.486988847583643
# radius= 3.1622776601683795 average number of neighbors for each spot is 18.304832713754646
#  Cluster 4 has neighbors:
# Dmain  10 :  351
# Dmain  0 :  197
# Dmain  8 :  142
# [10, 0, 8]
# SVGs for domain  4 : ['S100G', 'RAB11FIP1', 'BAMBI', 'DSP', 'BHLHE40', 'SNRPE', 'NDUFB9', 'PGK1', 'NPM1', 'EFNA1', 'TMEM150C', 'CD24', 'NME1', 'FOXA1', 'CSTA', 'DSTN', 'TOB1', 'HSPA1A', 'HEBP1', 'S100P', 'TFF3', 'LDHA', 'RPL26', 'XBP1', 'GPRC5A', 'SERPINA3', 'UQCRB', 'CSNK1A1', 'TFF1', 'NME2', 'MLPH', 'NDUFA1', 'ABHD2', 'YWHAE', 'RPL36AL', 'ATP5MD', 'HIST1H2AC', 'TOMM6', 'NDUFB1', 'TNFSF10', 'ACADSB', 'NQO1', 'CERS2', 'FAM234B', 'STC2', 'PPT1', 'COX7C', 'HIST1H4H', 'TBC1D9', 'EIF3H', 'HSPA5', 'LAPTM4B', 'AP2B1', 'ATP5PD', 'EIF3E', 'HSPD1', 'TPD52', 'MAL2', 'ENY2', 'IFT122', 'ERLIN2', 'SNHG6', 'GLO1', 'ZNF706', 'CLDN4', 'IL1R1', 'IFIT1', 'CPNE3', 'COX17', 'TBCA', 'COA3', 'ADIPOR1', 'SPCS1', 'REEP5', 'SEC61G', 'RERG', 'CTPS2', 'RBIS', 'POLR2K', 'H1F0', 'VDAC1', 'SSR1', 'HSPE1', 'COX14', 'MRPL13', 'SRARP', 'TMEM256', 'SYAP1', 'RPL22L1', 'TXNDC17', 'HSPA1B', 'SNHG16', 'WDR45B', 'PRDX4', 'TCEAL3', 'TMEM14C', 'PLPBP', 'PLEKHF2', 'MIEN1', 'C18orf32', 'IFITM1', 'SF3B6', 'SMS', 'TOR1AIP2', 'PSMD11', 'SLIRP', 'SMIM26', 'HK2', 'VIRMA', 'ZFAS1', 'LDLRAD4', 'ING1', 'TACSTD2', 'TFAP2A', 'EPCAM', 'GNL3', 'MUC5B', 'MCCC2', 'MRPS18B', 'CTBP2', 'LONP2', 'CRNDE', 'PRR15', 'CYB5A', 'TMEM14B', 'MRPS23', 'ELOC', 'BRF2', 'PDCD5', 'HEXIM1', 'NAA20', 'KAT6B', 'KIAA1324', 'GLRX5', 'TC2N', 'LGALS8', 'NDUFB3', 'DHRS7', 'C1QBP', 'CEBPD', 'BNIP3', 'ITPR1', 'SNHG8', 'PERP', 'BACE2', 'HMGB3', 'AL391001.1', 'NDUFAF6', 'KRT37', 'CITED2', 'KDM4B', 'ALB', 'AUTS2', 'GOLM1', 'SLC2A10', 'DYNC1LI1', 'NDRG1', 'RHOH', 'VAV3', 'FAM162A', 'SIX1', 'HIST1H2BD', 'GPC3', 'ILVBL', 'DECR1', 'ST8SIA6-AS1', 'MRPS28', 'BASP1', 'RPL7L1', 'RPAIN', 'SOX9', 'SERPINA5', 'DRAIC', 'ZNF350-AS1', 'SLC7A2', 'BOLA3', 'VEGFA', 'SOCS2', 'SRD5A3', 'WIPI1', 'KRT7', 'MRPL58', 'ALDOA', 'TATDN1', 'AC026355.2', 'ERP27', 'HPX', 'CDYL2', 'AC010168.2', 'OTUD6B-AS1', 'FUT8', 'AC093001.1', 'SPTSSB']

# %%
target=5
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 312.10877192982457]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 98.25614035087719]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 34.95789473684211]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 16.856140350877194]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [7.585964912280701, 16.856140350877194]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [7.585964912280701, 16.856140350877194]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=10.670175438596491
# radius= 3.1622776601683795 average number of neighbors for each spot is 16.856140350877194
#  Cluster 5 has neighbors:
# Dmain  3 :  681
# Dmain  0 :  635
# Dmain  6 :  337
# Dmain  9 :  302
# Dmain  7 :  194
# Dmain  2 :  166
# Dmain  12 :  132
# Dmain  10 :  107
# [3, 0, 6, 9, 7, 2, 12, 10]
# SVGs for domain  5 : ['COL1A2', 'C1QA', 'COL1A1', 'IGLC2', 'AEBP1', 'SFRP2', 'BGN', 'DCN', 'COMP']

# %%
target=6
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 273.0047619047619]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 100.49047619047619]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 38.352380952380955]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 18.62857142857143]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [8.266666666666667, 18.62857142857143]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [8.266666666666667, 18.62857142857143]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=11.728571428571428
# radius= 3.1622776601683795 average number of neighbors for each spot is 18.62857142857143
#  Cluster 6 has neighbors:
# Dmain  8 :  457
# Dmain  5 :  337
# Dmain  10 :  67
# [8, 5, 10]
# SVGs for domain  6 : ['SELENOP', 'H2AFZ', 'TFF1', 'RAB11FIP1', 'S100A14', 'MCCD1', 'LAPTM4B', 'SNCG', 'RAMP1', 'MAL2', 'WFDC2', 'HIST1H4H', 'MYC', 'C1QBP', 'EEF1A2', 'EIF4EBP1', 'CXCL9', 'PCED1B', 'BACE2', 'SLC7A5', 'MGST1', 'PTGES', 'AC010168.2']

# %%
target=7
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 338.68279569892474]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 115.98924731182795]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 42.36021505376344]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 20.091397849462364]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [8.725806451612904, 20.091397849462364]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [8.725806451612904, 20.091397849462364]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=12.53225806451613
# radius= 3.1622776601683795 average number of neighbors for each spot is 20.091397849462364
#  Cluster 7 has neighbors:
# Dmain  2 :  238
# Dmain  5 :  194
# Dmain  0 :  178
# Dmain  12 :  59
# [2, 5, 0, 12]
# SVGs for domain  7 : ['S100G', 'TSTD1', 'UGCG', 'RAB11FIP1', 'NDUFB9', 'ABCC5', 'TMED10', 'EFHD1', 'SKP1', 'TOB1', 'NDUFB1', 'BST2', 'COA3', 'JUND', 'PLAAT4', 'CLU', 'HIST1H2AC', 'STAT1', 'ZNF703', 'ANXA6', 'ATP6AP1', 'TMEM59', 'HSPA1A', 'FAM234B', 'DDR1', 'CSTA', 'IFT122', 'BAMBI', 'TPD52', 'TMCO1', 'ATP6V1G1', 'SCGB2A2', 'YWHAE', 'CD59', 'MYL12B', 'TBC1D9', 'CPNE3', 'CD24', 'MLPH', 'TAP1', 'UBE2L6', 'MIEN1', 'DSTN', 'UQCRB', 'COMT', 'ERGIC1', 'CITED4', 'C18orf32', 'HIST1H4H', 'WASHC5', 'FOXA1', 'PPT1', 'ARF4', 'REEP5', 'IFIT1', 'SCGB1D2', 'ERLIN2', 'ABHD2', 'NQO1', 'TMEM176A', 'ACLY', 'COX14', 'CA12', 'PRDX3', 'CTPS2', 'PARP9', 'PCED1B', 'BEX3', 'DAG1', 'SYAP1', 'XAF1', 'FBP1', 'CD47', 'GLO1', 'CYB5A', 'ARF3', 'AP2B1', 'SMS', 'POLR2K', 'H1F0', 'MB', 'SLC38A1', 'SDHC', 'APP', 'PPA1', 'CD55', 'NDUFA10', 'HERPUD1', 'COX17', 'ANO1', 'HEBP1', 'OAS2', 'MCCC2', 'STC2', 'ITPR1', 'TXNDC17', 'CYB5R1', 'ATP6V1C1', 'TOR1AIP2', 'GOT2', 'AP1M2', 'FARP1', 'ATP6V1E1', 'PRR15', 'MCCD1', 'PLPBP', 'PRLR', 'GSTM3', 'MRPL13', 'TMEM14C', 'LYPLA1', 'TFAP2A', 'AARS', 'GLUD1', 'KAT6B', 'BCL2', 'ORMDL2', 'GLRX5', 'PNPO', 'RERG', 'KRT37', 'ALDH9A1', 'HEXIM1', 'CERS6', 'WARS', 'ACSL3', 'PTPN1', 'AMFR', 'HIST1H2BD', 'DCAF10', 'C1QBP', 'DHRS7', 'AC087379.2', 'NBR1', 'FAM91A1', 'CGA', 'HIST2H2BE', 'SNCG', 'IFIT3', 'DYNC1LI1', 'APOL2', 'TOR1AIP1', 'DNAJC19', 'SEPHS2', 'TSPYL5', 'PISD', 'VAV3', 'AMIGO2', 'BRF2', 'ATP6V1H', 'EPHX1', 'HK2', 'SLC39A11', 'ECI2', 'ACKR3', 'DDIT3', 'SUMF1', 'TTC36', 'WNK4', 'TSKU', 'SIX1', 'SLC7A8', 'SLC7A2', 'CXCL9', 'TTC39A', 'AUTS2', 'RHOH', 'AFF3', 'FNIP1', 'DECR1', 'PIP4K2C', 'MRPS28', 'HCP5', 'KLHDC7B', 'CDYL2', 'AFMID', 'DRAIC', 'ABHD17C', 'WIPI1', 'SERPINA5', 'WFDC2', 'CD163L1', 'SLC7A5', 'ASB13', 'SLC19A2', 'BCAS1', 'ST8SIA6-AS1', 'SPTSSB', 'STK39', 'FUT8', 'RP1', 'TASOR2']

# %%
target=8
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 337.0285714285714]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 113.08163265306122]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 41.10612244897959]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 19.559183673469388]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [8.518367346938776, 19.559183673469388]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [8.518367346938776, 19.559183673469388]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=12.2
# radius= 3.1622776601683795 average number of neighbors for each spot is 19.559183673469388
#  Cluster 8 has neighbors:
# Dmain  6 :  457
# Dmain  10 :  199
# Dmain  4 :  142
# [6, 10, 4]
# SVGs for domain  8 : ['FASN', 'FAM234B', 'SCD', 'SCGB2A2', 'AMFR', 'PDCD4', 'HEBP1', 'WFDC2', 'SCGB1D2', 'RAMP1', 'ADORA2A', 'PTPN1', 'PDE5A', 'SFXN1', 'KCNE4']

# %%
target=9
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 378.6054054054054]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 123.17837837837838]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 43.6972972972973]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 20.556756756756755]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [8.881081081081081, 20.556756756756755]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [8.881081081081081, 20.556756756756755]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=12.783783783783784
# radius= 3.1622776601683795 average number of neighbors for each spot is 20.556756756756755
#  Cluster 9 has neighbors:
# Dmain  3 :  329
# Dmain  5 :  302
# Dmain  10 :  63
# [3, 5, 10]
# SVGs for domain  9 : ['TNFSF10', 'RBBP7', 'ITGB5', 'AGR2', 'BAMBI', 'SLC39A6', 'PVALB', 'IL1R1', 'TMEM150C', 'LINC00645', 'CPNE7', 'MUC5B', 'SRARP', 'AGR3', 'MGST3', 'IGFBP2', 'MLPH', 'ADORA2A', 'LDLRAD4', 'PLXNB2', 'ARHGAP8', 'DEGS1', 'ELP2', 'GFRA1', 'DAG1', 'SNRPD3', 'EFHD1', 'NEDD4L', 'TSPAN13', 'EXOC2', 'COLEC12', 'EEF1A2', 'ACKR3', 'KAT6B', 'COL2A1', 'SLC30A8', 'FGFR4', 'ST8SIA6-AS1', 'NVL', 'SOCS2', 'SLC7A8', 'VSTM2A', 'CLSTN2', 'NAT1', 'SHISA2', 'AC010998.3']

# %%
target=10
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 286.9158878504673]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 98.5607476635514]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 36.691588785046726]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 17.785046728971963]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [7.850467289719626, 17.785046728971963]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [7.850467289719626, 17.785046728971963]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=11.205607476635514
# radius= 3.1622776601683795 average number of neighbors for each spot is 17.785046728971963
#  Cluster 10 has neighbors:
# Dmain  4 :  351
# Dmain  0 :  342
# Dmain  8 :  199
# [4, 0, 8]
# SVGs for domain  10 : ['COL1A2', 'COL1A1', 'IGLC2', 'IGLC1', 'SFRP2', 'TAGLN', 'ALB']

# %%
target=11
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 285.9734513274336]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 109.93805309734513]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 42.16814159292036]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 20.123893805309734]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [8.716814159292035, 20.123893805309734]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [8.716814159292035, 20.123893805309734]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=12.530973451327434
# radius= 3.1622776601683795 average number of neighbors for each spot is 20.123893805309734
#  Cluster 11 has neighbors:
# Dmain  2 :  622
# [2]
# SVGs for domain  11 : ['PDCD4', 'PTGES', 'MDM2', 'USP14', 'ECM1', 'IER3', 'PDLIM1', 'UGCG', 'CYB5R1', 'SELENOP', 'NAT1', 'VTCN1', 'ALDH3B2', 'AC093001.1', 'ACADSB', 'ITPR1', 'ALDH2', 'ELP2', 'BAG3', 'GSTM3', 'SEPHS2', 'ABCC11', 'SIAH2', 'APOD', 'MUC19', 'ABCC12']

# %%
target=12
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 303.4691358024691]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 96.65432098765432]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 34.34567901234568]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 16.679012345679013]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [7.592592592592593, 16.679012345679013]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [7.592592592592593, 16.679012345679013]
# Calculateing adj matrix using xy only...
# recommended radius =  3.063392600044608 num_nbr=10.592592592592593
# radius= 3.1622776601683795 average number of neighbors for each spot is 16.679012345679013
#  Cluster 12 has neighbors:
# Dmain  0 :  254
# Dmain  1 :  176
# [0, 1]
# SVGs for domain  12 : ['IGFBP2', 'CAPS', 'SHISA2', 'SH3BGRL', 'KRT7']

# %%
target=14
#Set filtering criterials
min_in_group_fraction=0.8
min_in_out_group_ratio=1
min_fold_change=1.5
#Search radius such that each spot in the target domain has approximately 10 neighbors on average
adj_2d=spg.calculate_adj_matrix(x=x_array, y=y_array, histology=False)
start, end= np.quantile(adj_2d[adj_2d!=0],q=0.001), np.quantile(adj_2d[adj_2d!=0],q=0.1)
r=spg.search_radius(target_cluster=target, cell_id=adata.obs.index.tolist(), x=x_array, y=y_array, pred=adata.obs["pred"].tolist(), start=start, end=end, num_min=10, num_max=14,  max_run=100)
r = 3.1622776601683795
#Detect neighboring domains
#print(r)
nbr_domians=spg.find_neighbor_clusters(target_cluster=target,
                                   cell_id=adata.obs.index.tolist(), 
                                   x=adata.obs["array_row"].tolist(), 
                                   y=adata.obs["array_col"].tolist(), 
                                   pred=adata.obs["pred"].tolist(),
                                   radius=r,
                                   ratio=1/2)


print(nbr_domians)
nbr_domians=nbr_domians[0:3]

de_genes_info=spg.rank_genes_groups(input_adata=adata,
                                target_cluster=target,
                                nbr_list=nbr_domians, 
                                label_col="pred", 
                                adj_nbr=True, 
                                log=True)
#Filter genes
de_genes_info=de_genes_info[(de_genes_info["pvals_adj"]<0.05)]
filtered_info_domain_0=de_genes_info
filtered_info_domain_0=filtered_info_domain_0[(filtered_info_domain_0["pvals_adj"]<0.05) &
                            (filtered_info_domain_0["in_out_group_ratio"]>min_in_out_group_ratio) &
                            (filtered_info_domain_0["in_group_fraction"]>min_in_group_fraction) &
                            (filtered_info_domain_0["fold_change"]>min_fold_change)]
filtered_info_domain_0=filtered_info_domain_0.sort_values(by="in_group_fraction", ascending=False)
filtered_info_domain_0["target_dmain"]=target
filtered_info_domain_0["neighbors"]=str(nbr_domians)
print("SVGs for domain ", str(target),":", filtered_info_domain_0["genes"].tolist())
# Out:
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Calculateing adj matrix using xy only...
# Run 1: radius [1.4142135381698608, 16.492422103881836], num_nbr [1.0, 189.27777777777777]
# Calculateing adj matrix using xy only...
# Run 2: radius [1.4142135381698608, 8.953317821025848], num_nbr [1.0, 64.72222222222223]
# Calculateing adj matrix using xy only...
# Run 3: radius [1.4142135381698608, 5.183765679597855], num_nbr [1.0, 27.38888888888889]
# Calculateing adj matrix using xy only...
# Run 4: radius [1.4142135381698608, 3.2989896088838577], num_nbr [1.0, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 5: radius [2.3566015735268593, 3.2989896088838577], num_nbr [7.277777777777778, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 6: radius [2.8277955912053585, 3.2989896088838577], num_nbr [7.277777777777778, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 7: radius [3.063392600044608, 3.2989896088838577], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 8: radius [3.063392600044608, 3.181191104464233], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 9: radius [3.1222918522544205, 3.181191104464233], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 10: radius [3.1517414783593267, 3.181191104464233], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 11: radius [3.1517414783593267, 3.16646629141178], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 12: radius [3.1591038848855533, 3.16646629141178], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 13: radius [3.1591038848855533, 3.1627850881486665], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 14: radius [3.16094448651711, 3.1627850881486665], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 15: radius [3.1618647873328882, 3.1627850881486665], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 16: radius [3.1618647873328882, 3.1623249377407774], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 17: radius [3.162094862536833, 3.1623249377407774], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 18: radius [3.162209900138805, 3.1623249377407774], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 19: radius [3.1622674189397912, 3.1623249377407774], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 20: radius [3.1622674189397912, 3.1622961783402843], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 21: radius [3.1622674189397912, 3.1622817986400378], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 22: radius [3.1622746087899145, 3.1622817986400378], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 23: radius [3.1622746087899145, 3.162278203714976], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 24: radius [3.1622764062524453, 3.162278203714976], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 25: radius [3.1622773049837107, 3.162278203714976], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 26: radius [3.1622773049837107, 3.1622777543493434], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 27: radius [3.162277529666527, 3.1622777543493434], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 28: radius [3.1622776420079353, 3.1622777543493434], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 29: radius [3.1622776420079353, 3.1622776981786394], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 30: radius [3.1622776420079353, 3.162277670093287], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 31: radius [3.162277656050611, 3.162277670093287], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 32: radius [3.162277656050611, 3.162277663071949], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 33: radius [3.16227765956128, 3.162277663071949], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 34: radius [3.16227765956128, 3.1622776613166144], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 35: radius [3.16227765956128, 3.162277660438947], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 36: radius [3.1622776600001137, 3.162277660438947], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 37: radius [3.1622776600001137, 3.16227766021953], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 38: radius [3.162277660109822, 3.16227766021953], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 39: radius [3.1622776601646763, 3.16227766021953], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 40: radius [3.1622776601646763, 3.162277660192103], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 41: radius [3.1622776601646763, 3.1622776601783897], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 42: radius [3.1622776601646763, 3.162277660171533], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 43: radius [3.1622776601681046, 3.162277660171533], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 44: radius [3.1622776601681046, 3.162277660169819], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 45: radius [3.1622776601681046, 3.1622776601689617], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 46: radius [3.1622776601681046, 3.162277660168533], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 47: radius [3.1622776601683187, 3.162277660168533], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 48: radius [3.1622776601683187, 3.162277660168426], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 49: radius [3.1622776601683724, 3.162277660168426], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 50: radius [3.1622776601683724, 3.1622776601683995], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 51: radius [3.1622776601683724, 3.162277660168386], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 52: radius [3.162277660168379, 3.162277660168386], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 53: radius [3.162277660168379, 3.1622776601683826], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 54: radius [3.162277660168379, 3.162277660168381], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 55: radius [3.162277660168379, 3.16227766016838], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 56: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 57: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 58: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 59: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 60: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 61: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 62: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 63: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 64: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 65: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 66: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 67: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 68: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 69: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 70: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 71: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 72: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 73: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 74: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 75: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 76: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 77: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 78: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 79: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 80: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 81: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 82: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 83: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 84: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 85: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 86: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 87: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 88: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 89: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 90: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 91: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 92: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 93: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 94: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 95: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 96: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 97: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 98: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 99: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 100: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Calculateing adj matrix using xy only...
# Run 101: radius [3.162277660168379, 3.1622776601683795], num_nbr [9.555555555555555, 14.38888888888889]
# Exact radius not found, closest values are:
# radius=3.162277660168379: num_nbr=9.555555555555555
# radius=3.1622776601683795: num_nbr=14.38888888888889
# radius= 3.1622776601683795 average number of neighbors for each spot is 14.38888888888889
#  Cluster 14 has neighbors:
# No neighbor domain found, try bigger radius or smaller ratio.
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-619f251cd26b> in <module>
#      22
#      23 print(nbr_domians)
# ---> 24 nbr_domians=nbr_domians[0:3]
#      25
#      26 de_genes_info=spg.rank_genes_groups(input_adata=adata,
#
# TypeError: 'NoneType' object is not subscriptable
